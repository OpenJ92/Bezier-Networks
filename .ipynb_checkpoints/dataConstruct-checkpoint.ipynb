# %%
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
# pull training X and y data
X_train = pd.read_csv('X_train/X_train.csv')
y_train = pd.read_csv('y_train/y_train.csv')
X_test = pd.read_csv('X_test/X_test.csv')

# %%
def MIN_MAX(frame, _columns, columns_):
    min_max_scaler = preprocessing.MinMaxScaler()
    _frame = frame[_columns]
    frame_ = frame[columns_]
    frameV = frame_.values
    frameVScaled = min_max_scaler.fit_transform(frameV)
    frameVScaledframe = pd.DataFrame(frameVScaled)
    _frameframeVScaledframe = pd.concat([_frame, frameVScaledframe], axis = 1)
    _frameframeVScaledframe.columns = frame.columns
    return _frameframeVScaledframe

# %%
X_train = MIN_MAX(X_train, X_train.columns[:3], X_train.columns[3:])

# %%
labels = y_train['surface'].unique()
labels
# Out:
# array(['fine_concrete', 'concrete', 'soft_tiles', 'tiled', 'soft_pvc',
#        'hard_tiles_large_space', 'carpet', 'hard_tiles', 'wood'],
#       dtype=object)

# %%
def get_label_sid(label_index):
    return y_train[y_train['surface'] == labels[label_index]]['series_id'].values

# %%
X_train.dtypes
# Out:
# row_id                    object
# series_id                  int64
# measurement_number         int64
# orientation_X            float64
# orientation_Y            float64
# orientation_Z            float64
# orientation_W            float64
# angular_velocity_X       float64
# angular_velocity_Y       float64
# angular_velocity_Z       float64
# linear_acceleration_X    float64
# linear_acceleration_Y    float64
# linear_acceleration_Z    float64
# dtype: object

# %%
def construct_corrcoef_XXt(series_id, X, columns):
    return np.corrcoef(X[X['series_id'] == series_id][columns])

def construct_corrcoef_XtX(series_id, X, columns):
    return np.corrcoef(X[X['series_id'] == series_id][columns].T)

def construct_X(series_id, X, columns):
    return X[X['series_id'] == series_id][columns]

# %%
cols = X_train.columns[3:]
cols
# Out:
# Index(['orientation_X', 'orientation_Y', 'orientation_Z', 'orientation_W',
#        'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z',
#        'linear_acceleration_X', 'linear_acceleration_Y',
#        'linear_acceleration_Z'],
#       dtype='object')

# %% [markdown]
# ## Correleation Matrices as a basis for classifiaction
# Here, we seek to construct a Convolutional Autoencoder for the constructed Correleation Matrices. The latent vectors will contribute to our loss function through the maximization of a Calinski-Harabaz Index and a Minimization of Mean Square Error with the output.
#
# $$ \text{Loss} = \text{min}_{MSE}\text{max}_{CHI} \sum_{i} \sum_{j} (y_{ij} - y_{ij}^q)^{2} + \lambda \text{Calinski-Harabaz Index on latent vector space} $$
#
# I'm not sure if this will work, but I think it's worth a try...
#
# If this doesn't work, lets use the standard Varitational Autoencoder paradigm with the Calinkski-Harabaz Index as an additional regulrization term.

# %%
X = np.stack([construct_X(series_id, X_train, cols) for series_id in X_train['series_id'].unique()], axis = 2)
XXt = np.stack([construct_corrcoef_XXt(series_id, X_train, cols) for series_id in X_train['series_id'].unique()], axis = 2)
XtX = np.stack([construct_corrcoef_XtX(series_id, X_train, cols) for series_id in X_train['series_id'].unique()], axis = 2)

# %%
XXt.shape, XtX.shape, X.shape
# Out:
# ((128, 128, 3810), (10, 10, 3810), (128, 10, 3810))

# %%
# 3012
series_id = 77

# %%
def plot_corrcoef():
    fig = plt.figure(figsize = (16, 8))
    
    ax1 = plt.subplot2grid((2, 2), (0, 0), colspan = 2)
    ax2 = plt.subplot2grid((2, 2), (1, 1))
    ax3 = plt.subplot2grid((2, 2), (1, 0))
    
    ax1.matshow(X[:,:,series_id].T, cmap='tab20c')
    ax1.set_title('X')
    ax2.matshow(XXt[:,:,series_id], cmap='tab20c')
    ax2.set_title('XXt')
    ax3.matshow(XtX[:,:,series_id], cmap='tab20c')
    ax3.set_title('XtX')

# %%
plot_corrcoef()

# %% [markdown]
# ## Difference Tensor Structure First Order
# Look to construct a tensor whose elements are the normalized difference vectors ie. velocity (Conv2D)
# $$ T_{i, j, :} = \frac{A_i - A_j^T}{|A_i - A_j|} \text{ where } i \neq j, \text{ else } \frac{A_i}{|A_i|} $$
# This structure is an attempt to capture information on the nature of the change we see between data. Notice that $T_{i,j,:}$ is equivelent to the direction of change between the $i^{th}$ observation and the $j^{th}$ observation. Consider the addition of padding which represents the lengths of each of these vectors. Otherwise, this will be lost.

# %%
def APS(A):
    T = np.zeros(shape = (A.shape[0], A.shape[0], A.shape[1]))
    for i in range(A.shape[0]):
        for j in range(A.shape[0]):
            if i != j:
                T[i, j, :] = (A[i, :] - A.T[:, j]) / (np.linalg.norm(A[i, :] - A.T[:, j]))
            else:
                T[i, j, :] = A[i, :] / (np.linalg.norm(A[i, :]))
    return T

def APS_NN(A):
    T = np.zeros(shape = (A.shape[0], A.shape[0], A.shape[1]))
    for i in range(A.shape[0]):
        for j in range(A.shape[0]):
            if i != j:
                T[i, j, :] = (A[i, :] - A.T[:, j])
            else:
                T[i, j, :] = A[i, :]
    return T

# %%
X.shape
# Out:
# (128, 10, 3810)

# %%
#TBulk = np.stack([APS(X[:,:,i]) for i in X_train['series_id'].unique()], axis = 3)
#np.save('difftensorMINMAX.npy', TBulk)

#Bug: We transformed the series id and measurement number arguments. This cannot be the case as they're indicators, not direct measurements and 
#        we're using them as a basis for traversal here at the end of the code.
#Next: Look to create your normalized data and export to an npy file for later use. Perhaps prepare a pipeline for incoming data. Also think about
#        to capture increments of 10 -- 10-grams -- and train on them. maybe make a function that can produce from the full episode the internal 
#        n - grams. 

TBulk = np.load('feature/difftensorMINMAX.npy')
TBulk2 = np.load('feature/difftensor.npy')

# %%
T = TBulk[:,:,:,27]
T2 = TBulk2[:,:,:,27]

# %%
def plot_tensor_T(T_):
    fig, axes = plt.subplots(2, 5, figsize = (16, 8))
    for i in range(axes.shape[0]):
        for j in range(axes.shape[1]):
            axes[i,j].matshow(T_[:,:,axes.shape[1]*i + j], cmap='tab20c')
            axes[i,j].set_title(cols[axes.shape[1]*i + j])

# %%
plot_tensor_T(T)
plot_tensor_T(T2)

# %% [markdown]
# # Selecting 'n-grams' from diff Tensor

# %%
def pullSubIntervals(t, interval_num):
    return np.stack([t[i:(i+interval_num),i:(i+interval_num),:] for i in range(128 - interval_num)], axis = 3)

# %%
r = np.stack([pullSubIntervals(TBulk[:,:,:,series_id], 64) for i in get_label_sid(5)], axis = 4)

# %%
r[:,:,:,:,:].shape
# Out:
# (64, 64, 10, 64, 308)

# %% [markdown]
# # Difference nth order with one step
# see dataConstruct.py

# %%
A = np.load('feature/nOrderDiff.npy')

# %%
A = np.einsum('ijkl -> iklj', A)

# %%
A.shape
# Out:
# (3810, 128, 128, 10)

# %% [markdown]
# adjust vectors to unit length.

# %%
B = np.apply_along_axis(lambda x: x / np.linalg.norm(x), 3, A[:100, :, :, :])

# %%
plot_tensor_T(B[42,:,:,:])

# %% [markdown]
# # Apply Taylor Decay on psudo-derivatives
# Consider making this form symmetric in either direction. Because convolutions are additive, whenever we carry one out, we stand to cancel our progress out.

# %%
def taylorScale(nOrderSample):
    #nOrderSample = nOrderSample.astype(np.longdouble)
    for i in range(nOrderSample.shape[0]):
        for j in range(nOrderSample.shape[1]):
            try:
                nOrderSample[i,j,:] = (((-1)**(1 if i-j >= 0 else 0))*nOrderSample[i,j,:])/np.math.factorial(i-j if i-j >= 0 else j-i)
            except Exception as e:
                print(e)
                break
    return nOrderSample

# %%
W = taylorScale(A[150,:,:,:])
Y = taylorScale(A[1173,:,:,:])

# %%
plot_tensor_T(W)
plot_tensor_T(Y)

# %% [markdown]
# # 16-gram examples

# %%
w = lambda x, inter, T_: T_[x:x+inter, x:x+inter, :]

# %%
plot_tensor_T(w(50,32,W))
plot_tensor_T(w(50,32,Y))
